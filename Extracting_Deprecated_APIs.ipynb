# %%
import csv
import spacy

# %%
with open('replacement_information_post_processed_1.csv',encoding="utf-8",newline='') as f:
    reader = csv.reader(f)
    data = list(reader)

# %%
nlp = spacy.load('en_core_web_sm')

for i in range(len(data)):
    release_notes_name = data[i][0]
    if(len(data[i])>=2):
        for j in range(1,len(data[i])):
            print(data[i][j])
            doc = nlp(data[i][j])
            print("------------------------------")
            for ent in doc.ents:
                print(ent.text, ent.label_)
            print("------------------------------")
# Out:
# ['when passed objects that throw exceptions from tell, send them via chunked transfer encoding instead of failing.']
# ------------------------------
# ------------------------------
# ['clean up connections when we hit problems during chunked upload, rather than leaking them.']
# ------------------------------
# ------------------------------
# ['removed the previously deprecated keyword index from read_stata, statareader, and statareader.read, use index_col instead ']
# ------------------------------
# ------------------------------
# ['series.dt.week and series.dt.weekofyear are deprecated and will be removed in a future version, use series.dt.isocalendar.week instead ']
# ------------------------------
# 'series.dt.week DATE
# series.dt.weekofyear DATE
# ------------------------------
# ["removed the warn argument from open. instead a possibledatalosserror exception will be raised if you try to use mode='w' with an open file handle "]
# ------------------------------
# ...
